# %% [markdown]
# # 📊 SESIÓN 2: Medidas de Tendencia Central
# ## *Media, Mediana y Moda: El Corazón de la Estadística Descriptiva*
#
# ---
#
# ## 🎯 **Objetivos de Aprendizaje**
#
# Al finalizar esta sesión, serás capaz de:
# - ✅ Calcular e interpretar la media aritmética
# - ✅ Determinar la mediana y entender cuándo es preferible a la media
# - ✅ Identificar la moda en diferentes tipos de variables
# - ✅ Elegir la medida apropiada según el contexto
# - ✅ Analizar el impacto de valores atípicos (outliers)
# - ✅ Aplicar estas medidas tanto manualmente como con Python
#
# ---
#
# ## 📖 **PARTE 1: ¿Qué son las Medidas de Tendencia Central?**
#
# ### **🎯 Definición**
#
# > Las **medidas de tendencia central** son valores que representan el "centro" o "valor típico" de un conjunto de datos. Nos ayudan a resumir toda una distribución con un solo número representativo.
#
# ### **🤔 ¿Por qué son Importantes?**
#
# 1. **Simplificación**: Resumen miles de datos en un solo valor
# 2. **Comparación**: Permiten comparar diferentes grupos
# 3. **Comunicación**: Facilitan explicar resultados a otros
# 4. **Toma de Decisiones**: Base para decisiones informadas
# 5. **Punto de Referencia**: Centro alrededor del cual se distribuyen los datos
#
# ### **📊 Las Tres Medidas Principales**
#
# ```
# MEDIDAS DE TENDENCIA CENTRAL
# ├── MEDIA (Promedio)
# │   └── Suma todos los valores y divide entre n
# ├── MEDIANA (Valor central)
# │   └── Valor que divide los datos en dos mitades iguales
# └── MODA (Más frecuente)
#     └── Valor que aparece más veces
# ```
#
# ---
#
# ## 📊 **PARTE 2: La Media Aritmética**
#
# ### **🔢 Definición y Fórmula**
#
# La **media aritmética** (o simplemente "media") es el promedio de todos los valores en un conjunto de datos.
#
# #### **Para una Muestra:**
# ```
# x̄ = (x₁ + x₂ + x₃ + ... + xₙ) / n = Σx / n
# ```
#
# #### **Para una Población:**
# ```
# μ = (x₁ + x₂ + x₃ + ... + xₙ) / N = Σx / N
# ```
#
# **Donde:**
# - x̄ (x-barra) = media muestral
# - μ (mu) = media poblacional
# - Σx = suma de todos los valores
# - n = tamaño de la muestra
# - N = tamaño de la población
#
# ### **💡 Ejemplo Paso a Paso**
#
# **Situación**: Las edades de 7 empleados en una startup son: 25, 28, 22, 30, 26, 24, 29
#
# **Cálculo:**
# 1. Sumar todos los valores: 25 + 28 + 22 + 30 + 26 + 24 + 29 = 184
# 2. Dividir entre el número de empleados: 184 ÷ 7 = 26.29 años
# 3. **Interpretación**: La edad promedio de los empleados es 26.3 años
#
# ### **✅ Ventajas de la Media**
#
# 1. **Utiliza todos los datos**: Considera cada valor del conjunto
# 2. **Matemáticamente útil**: Permite cálculos adicionales
# 3. **Fácil de calcular**: Fórmula simple y directa
# 4. **Ampliamente conocida**: Todos entienden qué es un promedio
# 5. **Base para otros cálculos**: Varianza, desviación estándar, etc.
#
# ### **⚠️ Desventajas de la Media**
#
# 1. **Sensible a valores extremos**: Los outliers la afectan mucho
# 2. **No siempre representativa**: Puede no coincidir con ningún valor real
# 3. **Solo para datos numéricos**: No se puede calcular para datos categóricos
# 4. **Puede ser engañosa**: En distribuciones muy asimétricas
#
# ### **🎯 Ejemplo del Problema con Outliers**
#
# **Caso 1 - Sin outliers**: Salarios de 5 empleados
# - Datos: $30,000, $32,000, $31,000, $33,000, $29,000
# - Media: $31,000 ✅ *Representativa*
#
# **Caso 2 - Con outlier**: Mismo grupo + el CEO
# - Datos: $30,000, $32,000, $31,000, $33,000, $29,000, $500,000
# - Media: $109,167 ❌ *¡No representa a ningún empleado!*
#
# ---
#
# ## 📊 **PARTE 3: La Mediana**
#
# ### **🔢 Definición**
#
# > La **mediana** es el valor que divide un conjunto ordenado de datos en dos mitades iguales. El 50% de los datos está por debajo de la mediana y el 50% por encima.
#
# ### **📋 Pasos para Calcular la Mediana**
#
# 1. **Ordenar** los datos de menor a mayor
# 2. **Contar** el total de observaciones (n)
# 3. **Encontrar la posición**:
#    - Si n es impar: posición = (n + 1) ÷ 2
#    - Si n es par: promedio de las posiciones n÷2 y (n÷2) + 1
#
# ### **💡 Ejemplos Detallados**
#
# #### **Ejemplo 1 - Número impar de datos**
# **Datos**: Tiempo de espera en minutos: 5, 8, 12, 15, 20, 25, 30
#
# 1. Ya están ordenados ✅
# 2. n = 7 (impar)
# 3. Posición = (7 + 1) ÷ 2 = 4
# 4. **Mediana = 15 minutos**
#
# ```
# Posición: 1   2   3   4   5   6   7
# Valores:  5   8  12  15  20  25  30
#                     ↑
#                  Mediana
# ```
#
# #### **Ejemplo 2 - Número par de datos**
# **Datos**: Calificaciones: 85, 88, 90, 92, 95, 98
#
# 1. Ya están ordenados ✅
# 2. n = 6 (par)
# 3. Posiciones centrales: 6÷2 = 3 y 4
# 4. Valores en posiciones 3 y 4: 90 y 92
# 5. **Mediana = (90 + 92) ÷ 2 = 91**
#
# ```
# Posición: 1   2   3   4   5   6
# Valores: 85  88  90  92  95  98
#                 ↑   ↑
#             Mediana = 91
# ```
#
# ### **✅ Ventajas de la Mediana**
#
# 1. **Resistente a outliers**: Los valores extremos no la afectan
# 2. **Siempre representativa**: Divide los datos exactamente por la mitad
# 3. **Fácil de interpretar**: "La mitad está por debajo, la mitad por encima"
# 4. **Útil para datos ordinales**: Se puede calcular para datos ordenables
# 5. **Mejor para distribuciones asimétricas**: Más representativa que la media
#
# ### **⚠️ Desventajas de la Mediana**
#
# 1. **No usa toda la información**: Solo considera la posición, no los valores exactos
# 2. **Menos útil matemáticamente**: No permite tantos cálculos derivados
# 3. **Puede ser menos precisa**: Con pocos datos, puede no ser muy informativa
#
# ### **🎯 La Mediana vs Media con Outliers**
#
# Retomemos el ejemplo de los salarios:
#
# **Con outlier**: $29,000, $30,000, $31,000, $32,000, $33,000, $500,000
#
# - **Media**: $109,167 ❌ *Distorsionada*
# - **Mediana**: $(31,000 + 32,000) ÷ 2 = $31,500$ ✅ *Representativa*
#
# La mediana nos da una mejor idea del salario "típico" del empleado.
#
# ---
#
# ## 📊 **PARTE 4: La Moda**
#
# ### **🔢 Definición**
#
# > La **moda** es el valor o categoría que aparece con mayor frecuencia en un conjunto de datos. Es la única medida de tendencia central que se puede aplicar a todos los tipos de variables.
#
# ### **🏷️ Tipos de Distribuciones según la Moda**
#
# #### **1. Unimodal** - Una sola moda
# ```
# Frecuencia:  1  3  7  2  1
# Valores:     A  B  C  D  E
#                     ↑
#                   Moda
# ```
#
# #### **2. Bimodal** - Dos modas
# ```
# Frecuencia:  1  5  2  5  1
# Valores:     A  B  C  D  E
#                 ↑     ↑
#               Modas
# ```
#
# #### **3. Multimodal** - Múltiples modas
# ```
# Frecuencia:  4  2  4  1  4
# Valores:     A  B  C  D  E
#              ↑     ↑     ↑
#                Modas
# ```
#
# #### **4. Amodal** - Sin moda
# ```
# Frecuencia:  1  1  1  1  1
# Valores:     A  B  C  D  E
#          (Todos igual frecuencia)
# ```
#
# ### **💡 Ejemplos por Tipo de Variable**
#
# #### **Variables Categóricas**
# **Colores favoritos en una encuesta:**
# - Azul: 15 personas
# - Rojo: 8 personas
# - Verde: 12 personas
# - Amarillo: 5 personas
#
# **Moda: Azul** (mayor frecuencia)
#
# #### **Variables Numéricas Discretas**
# **Número de hijos por familia:**
# - 0 hijos: 3 familias
# - 1 hijo: 8 familias
# - 2 hijos: 12 familias ← **Moda**
# - 3 hijos: 5 familias
# - 4 hijos: 2 familias
#
# #### **Variables Numéricas Continuas**
# Para variables continuas, la moda se determina por:
# 1. **Agrupación en intervalos** (como en histogramas)
# 2. **El intervalo con mayor frecuencia** es modal
# 3. **Estimación del valor modal** dentro del intervalo
#
# ### **✅ Ventajas de la Moda**
#
# 1. **Aplicable a cualquier tipo de datos**: Categóricos, ordinales, numéricos
# 2. **Fácil de identificar**: Solo requiere contar frecuencias
# 3. **Resistente a outliers**: Los valores extremos no la afectan
# 4. **Útil para datos categóricos**: Única medida central posible
# 5. **Prácticamente útil**: "¿Qué es lo más común?"
#
# ### **⚠️ Desventajas de la Moda**
#
# 1. **Puede no existir**: Todos los valores con igual frecuencia
# 2. **Puede no ser única**: Múltiples modas posibles
# 3. **No usa toda la información**: Solo la frecuencia
# 4. **Menos estable**: Pequeños cambios pueden cambiar la moda
# 5. **Difícil para datos continuos**: Requiere agrupación
#
# ---
#
# ## ⚖️ **PARTE 5: ¿Cuándo Usar Cada Medida?**
#
# ### **🎯 Guía de Decisión**
#
# | Situación | Medida Recomendada | Razón |
# |-----------|-------------------|-------|
# | **Datos simétricos, sin outliers** | **Media** | Utiliza toda la información |
# | **Datos con outliers** | **Mediana** | No se ve afectada por extremos |
# | **Datos categóricos** | **Moda** | Única medida aplicable |
# | **Distribuciones asimétricas** | **Mediana** | Más representativa del centro |
# | **Análisis de tendencias populares** | **Moda** | Muestra lo más común |
# | **Cálculos matemáticos posteriores** | **Media** | Base para otras estadísticas |
#
# ### **📊 Relación entre las Medidas según la Forma de la Distribución**
#
# #### **Distribución Simétrica** (Curva Normal)
# ```
# Media = Mediana = Moda
# ```
# ![Simétrica: campana perfecta]
#
# #### **Distribución Asimétrica Positiva** (Cola hacia la derecha)
# ```
# Moda < Mediana < Media
# ```
# ![Asimétrica positiva: cola larga a la derecha]
#
# #### **Distribución Asimétrica Negativa** (Cola hacia la izquierda)
# ```
# Media < Mediana < Moda
# ```
# ![Asimétrica negativa: cola larga a la izquierda]
#
# ### **🎯 Casos de Estudio Prácticos**
#
# #### **Caso 1: Ingresos Familiares** 💰
# **Problema**: Los ingresos suelen tener distribución asimétrica (pocos muy ricos, muchos con ingresos moderados)
#
# **Datos ejemplo**: $25K, $30K, $32K, $35K, $38K, $40K, $200K
# - Media: $57K ❌ *Sobrestima el ingreso típico*
# - Mediana: $35K ✅ *Mejor representación*
# - **Recomendación**: Usar mediana
#
# #### **Caso 2: Calificaciones de Examen** 📚
# **Problema**: Calificaciones tienden a ser simétricas alrededor del promedio
#
# **Datos ejemplo**: 65, 70, 75, 78, 80, 82, 85, 88, 90
# - Media: 79.2 ✅ *Representativa*
# - Mediana: 80 ✅ *También representativa*
# - **Recomendación**: Cualquiera es válida, media es más común
#
# #### **Caso 3: Preferencias de Marca** 🏪
# **Problema**: Queremos saber qué marca es más popular
#
# **Datos**: Nike (45%), Adidas (30%), Puma (15%), Otras (10%)
# - Moda: Nike ✅ *Única medida aplicable*
# - **Recomendación**: Solo la moda tiene sentido
#
# ---
#
# ## 🧠 **PARTE 6: Conceptos Avanzados**
#
# ### **📊 Media Ponderada**
#
# Cuando algunos valores tienen más "peso" o importancia que otros:
#
# **Fórmula**:
# ```
# x̄ₚ = Σ(wᵢ × xᵢ) / Σwᵢ
# ```
#
# **Ejemplo**: Calificación final del curso
# - Parciales (20% cada uno): 85, 90
# - Final (60%): 78
#
# **Cálculo**:
# ```
# Calificación = (0.20×85) + (0.20×90) + (0.60×78)
#              = 17 + 18 + 46.8 = 81.8
# ```
#
# ### **📊 Media Geométrica**
#
# Útil para tasas de crecimiento, porcentajes, ratios:
#
# **Fórmula**:
# ```
# Media Geométrica = ⁿ√(x₁ × x₂ × ... × xₙ)
# ```
#
# **Ejemplo**: Crecimiento anual de ventas: +10%, +20%, -5%
# ```
# Media Geométrica = ³√(1.10 × 1.20 × 0.95) = ³√1.254 = 1.078
# Crecimiento promedio anual = 7.8%
# ```
#
# ### **📊 Media Armónica**
#
# Útil para promediar velocidades, tasas, ratios:
#
# **Fórmula**:
# ```
# Media Armónica = n / (1/x₁ + 1/x₂ + ... + 1/xₙ)
# ```
#
# **Ejemplo**: Velocidades promedio en un viaje de ida y vuelta
# - Ida: 60 km/h
# - Vuelta: 40 km/h
# - Media armónica: 2/(1/60 + 1/40) = 48 km/h
#
# ---
#
# ## 🎯 **PARTE 7: Preparación para la Práctica**
#
# ### **💻 Lo que Implementaremos**
#
# 1. **Cálculo manual vs automático** de todas las medidas
# 2. **Análisis del impacto de outliers** con ejemplos reales
# 3. **Visualización** de medidas de tendencia central
# 4. **Casos prácticos** de decisión entre medidas
# 5. **Aplicación a nuestros datasets** de estudiantes e iris
#
# ### **🎯 Preguntas de Autoevaluación**
#
# Antes de la práctica, asegúrate de poder responder:
#
# 1. **¿Cuándo preferirías la mediana sobre la media?**
# 2. **¿Por qué la moda es útil para datos categóricos?**
# 3. **¿Cómo afectan los outliers a cada medida?**
# 4. **¿Qué nos dice la relación entre media y mediana sobre la forma de la distribución?**
#
# ### **💡 Consejo Clave**
#
# > *"No existe una medida de tendencia central 'correcta' universal. La elección depende del tipo de datos, la distribución y el objetivo del análisis. Un buen estadístico siempre considera el contexto."*
#
# ---
#
# ## 🚀 **Próximo Paso: Práctica con Python**
#
# En la implementación práctica veremos cómo Python nos facilita estos cálculos y cómo visualizar las diferencias entre las medidas con datos reales. ¡Prepárate para poner en práctica todo lo aprendido!

# %% [markdown]
# # 📊 PRÁCTICA
# ##  Media, Mediana y Moda: Implementación y Análisis Práctico

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
from sklearn.datasets import load_iris
warnings.filterwarnings('ignore')

# %%
# Dataset Iris
iris_data = load_iris()
iris_df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)
iris_df['species'] = iris_data.target
iris_df['species'] = iris_df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# %% [markdown]
# # CÁLCULO MANUAL DE MEDIDAS DE TENDENCIA CENTRAL

# %%
print("🧮 CÁLCULO MANUAL VS AUTOMÁTICO - COMPRENDIENDO LOS CONCEPTOS")
print("="*70)

# Tomemos una muestra pequeña para cálculo manual
sample_ages = [18, 19, 20, 20, 21, 22, 24, 25, 28, 35]
print(f"📊 Muestra de edades para análisis: {sample_ages}")

# MEDIA ARITMÉTICA - Cálculo manual
print("\n1️⃣ MEDIA ARITMÉTICA:")
suma_manual = sum(sample_ages)
n_manual = len(sample_ages)
media_manual = suma_manual / n_manual

print(f"   📋 Cálculo paso a paso:")
print(f"      Suma de valores: {' + '.join(map(str, sample_ages))} = {suma_manual}")
print(f"      Número de datos: {n_manual}")
print(f"      Media = {suma_manual} ÷ {n_manual} = {media_manual:.2f} años")

# Comparar con cálculo automático
media_numpy = np.mean(sample_ages)
media_pandas = pd.Series(sample_ages).mean()

print(f"   🐍 Python - numpy: {media_numpy:.2f}")
print(f"   🐼 Python - pandas: {media_pandas:.2f}")
print(f"   ✅ ¡Los resultados coinciden!")

# MEDIANA - Cálculo manual
print("\n2️⃣ MEDIANA:")
sample_sorted = sorted(sample_ages)
print(f"   📋 Datos ordenados: {sample_sorted}")
print(f"   📏 Número de datos: {len(sample_sorted)} (par)")

# Para número par de datos
pos1 = len(sample_sorted) // 2 - 1  # Posición antes del centro (índice)
pos2 = len(sample_sorted) // 2      # Posición después del centro (índice)
mediana_manual = (sample_sorted[pos1] + sample_sorted[pos2]) / 2

print(f"   📍 Posiciones centrales: {pos1+1} y {pos2+1} (valores: {sample_sorted[pos1]} y {sample_sorted[pos2]})")
print(f"   🎯 Mediana = ({sample_sorted[pos1]} + {sample_sorted[pos2]}) ÷ 2 = {mediana_manual:.1f} años")

# Comparar con cálculo automático
mediana_numpy = np.median(sample_ages)
mediana_pandas = pd.Series(sample_ages).median()

print(f"   🐍 Python - numpy: {mediana_numpy:.1f}")
print(f"   🐼 Python - pandas: {mediana_pandas:.1f}")
print(f"   ✅ ¡Los resultados coinciden!")

# MODA - Cálculo manual
print("\n3️⃣ MODA:")
from collections import Counter
contador = Counter(sample_ages)
print(f"   📊 Frecuencias: {dict(contador)}")

# Encontrar el valor(es) con mayor frecuencia
max_frecuencia = max(contador.values())
modas = [valor for valor, freq in contador.items() if freq == max_frecuencia]

print(f"   🔝 Frecuencia máxima: {max_frecuencia}")
print(f"   🎯 Moda(s): {modas}")

# Comparar con cálculo automático usando scipy.stats
moda_scipy = stats.mode(sample_ages, keepdims=True)
print(f"   🐍 Python - scipy: {moda_scipy.mode[0]} (frecuencia: {moda_scipy.count[0]})")
# Out:
# 🧮 CÁLCULO MANUAL VS AUTOMÁTICO - COMPRENDIENDO LOS CONCEPTOS
# ...
# 📊 Muestra de edades para análisis: [18, 19, 20, 20, 21, 22, 24, 25, 28, 35]
#
# 1️⃣ MEDIA ARITMÉTICA:
#    📋 Cálculo paso a paso:
#       Suma de valores: 18 + 19 + 20 + 20 + 21 + 22 + 24 + 25 + 28 + 35 = 232
#       Número de datos: 10
#       Media = 232 ÷ 10 = 23.20 años
#    🐍 Python - numpy: 23.20
#    🐼 Python - pandas: 23.20
#    ✅ ¡Los resultados coinciden!
#
# 2️⃣ MEDIANA:
#    📋 Datos ordenados: [18, 19, 20, 20, 21, 22, 24, 25, 28, 35]
#    📏 Número de datos: 10 (par)
#    📍 Posiciones centrales: 5 y 6 (valores: 21 y 22)
#    🎯 Mediana = (21 + 22) ÷ 2 = 21.5 años
#    🐍 Python - numpy: 21.5
#    🐼 Python - pandas: 21.5
#    ✅ ¡Los resultados coinciden!
#
# 3️⃣ MODA:
#    📊 Frecuencias: {18: 1, 19: 1, 20: 2, 21: 1, 22: 1, 24: 1, 25: 1, 28: 1, 35: 1}
#    🔝 Frecuencia máxima: 2
#    🎯 Moda(s): [20]
#    🐍 Python - scipy: 20 (frecuencia: 2)

# %% [markdown]
# # ANÁLISIS DEL IMPACTO DE OUTLIERS

# %%
print("\n" + "="*70)
print("🎯 IMPACTO DE VALORES ATÍPICOS (OUTLIERS)")
print("="*70)

# Datos SIN outliers
datos_normales = [30, 32, 31, 33, 29, 35, 28, 34, 30, 32]
print(f"📊 Salarios normales (en miles): {datos_normales}")

media_normal = np.mean(datos_normales)
mediana_normal = np.median(datos_normales)
moda_normal = stats.mode(datos_normales, keepdims=True).mode[0]

print(f"   Media: ${media_normal:.1f}K")
print(f"   Mediana: ${mediana_normal:.1f}K") 
print(f"   Moda: ${moda_normal}K")

# Datos CON outlier (agregar CEO con salario alto)
datos_con_outlier = datos_normales + [500]  # CEO gana $500K
print(f"\n📊 Salarios CON outlier (CEO): {datos_con_outlier}")

media_outlier = np.mean(datos_con_outlier)
mediana_outlier = np.median(datos_con_outlier)
moda_outlier = stats.mode(datos_con_outlier, keepdims=True).mode[0]

print(f"   Media: ${media_outlier:.1f}K")
print(f"   Mediana: ${mediana_outlier:.1f}K")
print(f"   Moda: ${moda_outlier}K")

# Análisis del impacto
print(f"\n📈 IMPACTO DEL OUTLIER:")
cambio_media = ((media_outlier - media_normal) / media_normal) * 100
cambio_mediana = ((mediana_outlier - mediana_normal) / mediana_normal) * 100

print(f"   Media cambió: {cambio_media:.1f}% 📈 ¡MUY AFECTADA!")
print(f"   Mediana cambió: {cambio_mediana:.1f}% 📊 Prácticamente sin cambio")

# Visualización del impacto de outliers
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Gráfico 1: Sin outlier
ax1.hist(datos_normales, bins=8, alpha=0.7, color='skyblue', edgecolor='black')
ax1.axvline(media_normal, color='red', linestyle='--', linewidth=2, label=f'Media: ${media_normal:.1f}K')
ax1.axvline(mediana_normal, color='green', linestyle='--', linewidth=2, label=f'Mediana: ${mediana_normal:.1f}K')
ax1.set_title('Distribución SIN Outlier')
ax1.set_xlabel('Salario (miles)')
ax1.set_ylabel('Frecuencia')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Gráfico 2: Con outlier
ax2.hist(datos_con_outlier, bins=10, alpha=0.7, color='coral', edgecolor='black')
ax2.axvline(media_outlier, color='red', linestyle='--', linewidth=2, label=f'Media: ${media_outlier:.1f}K')
ax2.axvline(mediana_outlier, color='green', linestyle='--', linewidth=2, label=f'Mediana: ${mediana_outlier:.1f}K')
ax2.set_title('Distribución CON Outlier')
ax2.set_xlabel('Salario (miles)')
ax2.set_ylabel('Frecuencia')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"💡 CONCLUSIÓN: La mediana es más ROBUSTA ante outliers que la media")
# Out:
# ...
# 🎯 IMPACTO DE VALORES ATÍPICOS (OUTLIERS)
# ...
# 📊 Salarios normales (en miles): [30, 32, 31, 33, 29, 35, 28, 34, 30, 32]
#    Media: $31.4K
#    Mediana: $31.5K
#    Moda: $30K
#
# 📊 Salarios CON outlier (CEO): [30, 32, 31, 33, 29, 35, 28, 34, 30, 32, 500]
#    Media: $74.0K
#    Mediana: $32.0K
#    Moda: $30K
#
# 📈 IMPACTO DEL OUTLIER:
#    Media cambió: 135.7% 📈 ¡MUY AFECTADA!
#    Mediana cambió: 1.6% 📊 Prácticamente sin cambio
# 💡 CONCLUSIÓN: La mediana es más ROBUSTA ante outliers que la media

# %% [markdown]
# # VISUALIZACIÓN AVANZADA DE MEDIDAS DE TENDENCIA CENTRAL

# %%
print("\n" + "="*70)
print("📊 VISUALIZACIÓN AVANZADA - DISTRIBUCIONES Y MEDIDAS CENTRALES")
print("="*70)

# Crear visualización de 3 variables numéricas
fig, axes = plt.subplots(2, 4, figsize=(18, 12))
fig.suptitle('Medidas de Tendencia Central en Dataset de Estudiantes', fontsize=16, y=0.98)

variables_plot = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)']

for i, var in enumerate(variables_plot):
    datos = iris_df[var]
    
    # Histograma con medidas centrales (fila superior)
    ax1 = axes[0, i]
    ax1.hist(datos, bins=20, alpha=0.7, color='lightblue', edgecolor='black')
    
    media = datos.mean()
    mediana = datos.median()
    moda_vals = datos.mode()
    if len(moda_vals) > 0:
        moda = moda_vals.iloc[0]
        ax1.axvline(moda, color='orange', linestyle=':', linewidth=2, label=f'Moda: {moda:.1f}')
    
    ax1.axvline(media, color='red', linestyle='--', linewidth=2, label=f'Media: {media:.1f}')
    ax1.axvline(mediana, color='green', linestyle='-', linewidth=2, label=f'Mediana: {mediana:.1f}')
    
    ax1.set_title(f'Distribución de {var.replace("_", " ").title()}')
    ax1.set_xlabel(var.replace("_", " ").title())
    ax1.set_ylabel('Frecuencia')
    ax1.legend(fontsize=8)
    ax1.grid(True, alpha=0.3)
    
    # Box plot (fila inferior)
    ax2 = axes[1, i]
    box_data = ax2.boxplot([datos], labels=[var.replace("_", " ").title()], patch_artist=True)
    box_data['boxes'][0].set_facecolor('lightgreen')
    box_data['boxes'][0].set_alpha(0.7)
    
    # Agregar media al boxplot
    ax2.plot(1, media, 'ro', markersize=8, label=f'Media: {media:.1f}')
    ax2.set_title(f'Box Plot - {var.replace("_", " ").title()}')
    ax2.legend(fontsize=8)
    ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ...
# 📊 VISUALIZACIÓN AVANZADA - DISTRIBUCIONES Y MEDIDAS CENTRALES
# ...

# %% [markdown]
# # ANÁLISIS DE VARIABLES CATEGÓRICAS CON MODA

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

print("\n" + "="*70)
print("🏷️ ANÁLISIS DE VARIABLES CATEGÓRICAS - SOLO LA MODA APLICA")
print("="*70)

variables_categoricas = ['species']

for var in variables_categoricas:
    print(f"\n📊 {var.upper()}:")
    
    # Calcular frecuencias
    frecuencias = iris_df[var].value_counts()
    porcentajes = iris_df[var].value_counts(normalize=True) * 100
    
    # La moda es la categoría con mayor frecuencia
    moda_cat = frecuencias.index[0]
    freq_moda = frecuencias.iloc[0]
    pct_moda = porcentajes.iloc[0]
    
    print(f"   🏆 MODA: {moda_cat}")
    print(f"   📈 Frecuencia: {freq_moda} ({pct_moda:.1f}%)")
    print(f"\n   📋 Distribución completa:")
    
    for categoria, freq in frecuencias.items():
        pct = (freq / len(iris_df)) * 100
        barra = "█" * int(pct / 2)  # Barra visual
        print(f"      {categoria:12}: {freq:3d} ({pct:5.1f}%) {barra}")

# ==========================================
# 🔍 Visualización de la variable categórica
# ==========================================

# Crear figura
fig, ax = plt.subplots(figsize=(7, 6))

# Datos
genero_counts = iris_df['species'].value_counts()
colors1 = ['lightcoral', 'lightblue', 'lightgreen']

# Gráfico de pastel
ax.pie(genero_counts.values,
       labels=genero_counts.index,
       autopct='%1.1f%%',
       colors=colors1,
       startangle=90,
       textprops={'fontsize': 12})

# Título con la moda
ax.set_title('Distribución por Especie\n(Moda: ' + genero_counts.index[0] + ')', fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# ...
# 🏷️ ANÁLISIS DE VARIABLES CATEGÓRICAS - SOLO LA MODA APLICA
# ...
#
# 📊 SPECIES:
#    🏆 MODA: setosa
#    📈 Frecuencia: 50 (33.3%)
#
#    📋 Distribución completa:
#       setosa      :  50 ( 33.3%) ████████████████
#       versicolor  :  50 ( 33.3%) ████████████████
#       virginica   :  50 ( 33.3%) ████████████████

# %% [markdown]
# ### **2. Decisiones por Contexto**
# | Situación | Medida Recomendada | Razón |
# |-----------|-------------------|-------|
# | Salarios empresariales | **Mediana** | Evita distorsión por altos ejecutivos |
# | Calificaciones de clase | **Media** | Distribución simétrica, usa toda la información |
# | Talla de camisetas | **Moda** | Datos categóricos, indica mayor demanda |
#
# ### **3. Análisis de Forma Distributiva**
# - **Media = Mediana = Moda** → Distribución simétrica
# - **Media > Mediana** → Asimétrica positiva (cola derecha)
# - **Media < Mediana** → Asimétrica negativa (cola izquierda)
#
# ---
#
# ## ⚖️ **Guía de Decisión Práctica**
#
# ### **🔍 Proceso de Selección**
# ```
# 1. ¿Qué tipo de variable?
#    ├─ Categórica → MODA
#    └─ Numérica → Continúa...
#
# 2. ¿Hay outliers evidentes?
#    ├─ Sí → MEDIANA
#    └─ No → Continúa...
#
# 3. ¿La distribución es simétrica?
#    ├─ Sí → MEDIA
#    └─ No → MEDIANA
#
# 4. ¿Necesitas cálculos posteriores?
#    ├─ Sí → MEDIA (si es apropiada)
#    └─ No → Cualquiera apropiada
# ```
#
# ---
#
# ## 💡 **Mejores Prácticas Establecidas**
#
# ### **✅ Buenas Prácticas**
# 1. **Siempre visualiza primero**: Usa histogramas y box plots
# 2. **Calcula las tres medidas**: Cuando sea posible para comparar
# 3. **Considera el contexto**: La "mejor" medida depende del objetivo
# 4. **Documenta tu decisión**: Explica por qué elegiste cierta medida
# 5. **Presenta claramente**: Usa unidades y contexto apropiados
#
# ### **❌ Errores Comunes a Evitar**
# 1. Usar solo la media sin considerar outliers
# 2. Aplicar media a datos categóricos
# 3. Ignorar la forma de la distribución
# 4. No visualizar los datos antes del análisis
# 5. Presentar resultados sin contexto o interpretación
#
# ---
#
# ## 📊 **Visualizaciones Clave Dominadas**
#
# ### **Tipos de Gráficos para Medidas Centrales**
# - **Histogramas con líneas verticales**: Mostrar media, mediana, moda
# - **Box plots**: Visualizar mediana, cuartiles y outliers
# - **Gráficos de barras**: Para frecuencias y moda en datos categóricos
# - **Comparaciones por grupos**: Box plots múltiples
#
# ---
#
# ## 🧮 **Conceptos Matemáticos Avanzados**
#
# ### **Medias Especializadas** (Introducidas)
# - **Media Ponderada**: Para datos con diferentes pesos
# - **Media Geométrica**: Para tasas de crecimiento
# - **Media Armónica**: Para velocidades y razones
#
# ### **Relación con Forma Distributiva**
# - Comprensión de cómo las medidas revelan características distributivas
# - Identificación visual de simetría/asimetría
#
# ---
#
# ## 🚀 **Preparación para Sesión 3: Medidas de Dispersión**
#
# ### **📋 Conceptos Previos Necesarios**
# - ✅ Cálculo de media (base para varianza)
# - ✅ Interpretación de distribuciones
# - ✅ Manejo de outliers
# - ✅ Visualización con Python
#
# ### **🎯 Vista Previa: ¿Qué Aprenderemos?**
# - **Varianza y Desviación Estándar**: ¿Qué tan dispersos están los datos?
# - **Rango y Rango Intercuartílico**: Medidas simples de variabilidad
# - **Coeficiente de Variación**: Comparación de dispersión entre variables
# - **Regla Empírica**: 68-95-99.7 en distribuciones normales
#
# ### **💡 Pregunta Clave para Reflexionar**
# *"Dos grupos pueden tener la misma media, pero comportamientos muy diferentes. ¿Cómo medimos y comparamos esta variabilidad?"*
#
# ---
#
# ## 📚 **Recursos de Refuerzo**
#
# ### **💻 Práctica Adicional Sugerida**
# ```python
# # Ejercicios para consolidar
# # 1. Crear datasets con diferentes formas
# datos_simetricos = np.random.normal(50, 10, 100)
# datos_asimetricos = np.random.exponential(2, 100)
#
# # 2. Comparar medidas
# print(f"Simétricos - Media: {np.mean(datos_simetricos):.2f}, Mediana: {np.median(datos_simetricos):.2f}")
# print(f"Asimétricos - Media: {np.mean(datos_asimetricos):.2f}, Mediana: {np.median(datos_asimetricos):.2f}")
#
# # 3. Experimentar con outliers
# datos_con_outlier = list(datos_simetricos) + [200]  # Agregar outlier extremo
# ```
#
# ### **🔗 Enlaces Útiles**
# - [Khan Academy - Central Tendency](https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/mean-median-basics/a/mean-median-and-mode-review)
# - [StatQuest - Mean, Median, Mode](https://www.youtube.com/watch?v=h8EYEJ32oQ8)
# - [Pandas Documentation - Descriptive Statistics](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
#
# ---
#
# ## 💬 **Reflexión Final**
#
# > *"Las medidas de tendencia central nos dan el 'centro' de nuestros datos, pero solo cuentan la mitad de la historia. En la próxima sesión descubriremos cómo medir qué tan dispersos están los datos alrededor de ese centro, completando así nuestra comprensión de las distribuciones."*
#
# **🚀 ¡Estás construyendo una base sólida en estadística descriptiva! La próxima sesión agregará una dimensión crucial: la variabilidad.**
