# %% [markdown]
# # 📊 SESIÓN 7: Análisis Bivariado
#
# ---
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar esta sesión serás capaz de:
# - Analizar relaciones entre dos variables de diferentes tipos
# - Calcular e interpretar coeficientes de correlación
# - Crear y analizar tablas de contingencia
# - Realizar análisis de asociación estadística
# - Visualizar relaciones bivariadas de manera efectiva
#
# ---
#
# ## 📖 FUNDAMENTOS TEÓRICOS
#
# ### ¿Qué es el Análisis Bivariado?
#
# El análisis bivariado es el estudio estadístico de **dos variables simultáneamente** para determinar si existe una relación entre ellas. Mientras que el análisis univariado se centra en describir cada variable por separado, el análisis bivariado nos permite:
#
# - **Identificar patrones de relación** entre variables
# - **Cuantificar la fuerza** de estas relaciones
# - **Determinar la dirección** (positiva o negativa) de la relación
# - **Evaluar la independencia** estadística entre variables
#
# ### Tipos de Relaciones Bivariadas
#
# Dependiendo del tipo de variables que analicemos, tenemos diferentes enfoques:
#
# | Variable 1 | Variable 2 | Análisis Apropiado |
# |------------|------------|-------------------|
# | Cuantitativa | Cuantitativa | **Correlación** (Pearson, Spearman) |
# | Categórica | Categórica | **Tablas de contingencia**, Chi-cuadrado |
# | Categórica | Cuantitativa | **Comparación de grupos**, ANOVA |
#
# ---
#
# ## 1. ANÁLISIS DE CORRELACIÓN
#
# ### 1.1 Conceptos Fundamentales
#
# La **correlación** mide la fuerza y dirección de la relación lineal entre dos variables cuantitativas.
#
# #### Características importantes:
# - **Rango**: Los coeficientes de correlación van de -1 a +1
# - **Interpretación**:
#   - **r = +1**: Correlación positiva perfecta
#   - **r = 0**: No hay correlación lineal
#   - **r = -1**: Correlación negativa perfecta
#
# #### Interpretación práctica:
# - **|r| > 0.7**: Correlación fuerte
# - **0.3 < |r| ≤ 0.7**: Correlación moderada
# - **|r| ≤ 0.3**: Correlación débil
#
# ### 1.2 Correlación de Pearson
#
# **Cuándo usarla:**
# - Ambas variables son cuantitativas
# - La relación es aproximadamente lineal
# - Los datos siguen distribución normal (aproximadamente)
#
# **Fórmula conceptual:**
# ```
# r = Σ[(xi - x̄)(yi - ȳ)] / √[Σ(xi - x̄)² × Σ(yi - ȳ)²]
# ```
#
# **Ejemplo conceptual:**
# Imagina que queremos estudiar la relación entre:
# - **Años de educación** (Variable X)
# - **Ingresos anuales** (Variable Y)
#
# Si r = 0.65, interpretaríamos que existe una correlación positiva moderada: a mayor educación, tiende a haber mayores ingresos.
#
# ### 1.3 Correlación de Spearman
#
# **Cuándo usarla:**
# - Variables ordinales o cuantitativas que no siguen distribución normal
# - La relación es monótona pero no necesariamente lineal
# - Presencia de valores atípicos
#
# **Ventaja principal:** Es más robusta ante outliers porque trabaja con rangos.
#
# ### 1.4 ⚠️ Correlación vs. Causalidad
#
# **IMPORTANTE:** La correlación NO implica causalidad.
#
# - **Correlación alta** significa que las variables varían juntas
# - **Causalidad** significa que una variable causa cambios en otra
# - Pueden existir **variables confusoras** que expliquen ambas relaciones
#
# **Ejemplo:**
# - Correlación: Ventas de helados y ahogamientos (r = 0.8)
# - Variable confusora: Temperatura (a mayor temperatura, más ventas de helados Y más gente en piscinas)
#
# ---
#
# ## 2. TABLAS DE CONTINGENCIA
#
# ### 2.1 Concepto y Construcción
#
# Una **tabla de contingencia** (o tabla cruzada) muestra la distribución de frecuencias de dos variables categóricas simultáneamente.
#
# #### Estructura básica:
# ```
#                       Variable Y
#                   Cat1  Cat2  Cat3  Total
# Variable X  Cat1   n11   n12   n13   n1+
#             Cat2   n21   n22   n23   n2+
#             Total  n+1   n+2   n+3    n
# ```
#
# Donde:
# - **nij**: frecuencia de la combinación categoría i de X con categoría j de Y
# - **ni+**: total marginal de la fila i
# - **n+j**: total marginal de la columna j
#
# ### 2.2 Tipos de Frecuencias
#
# 1. **Frecuencias absolutas**: Conteos directos
# 2. **Frecuencias relativas**: Proporciones del total general
# 3. **Frecuencias condicionales**:
#    - Por filas: proporción dentro de cada fila
#    - Por columnas: proporción dentro de cada columna
#
# ### 2.3 Análisis de Independencia
#
# Dos variables categóricas son **independientes** si el conocimiento de una no nos proporciona información sobre la otra.
#
# **Hipótesis:**
# - **H₀**: Las variables son independientes
# - **H₁**: Las variables están asociadas
#
# ---
#
# ## 3. MEDIDAS DE ASOCIACIÓN
#
# ### 3.1 Chi-cuadrado de Pearson
#
# **Propósito:** Evaluar si existe asociación entre dos variables categóricas.
#
# **Fórmula:**
# ```
# χ² = Σ[(Observado - Esperado)² / Esperado]
# ```
#
# **Interpretación:**
# - **χ² = 0**: Independencia perfecta
# - **χ² > 0**: Indica grado de asociación (mayor valor = mayor asociación)
#
# ### 3.2 Proceso de la Prueba Chi-cuadrado
#
# 1. **Plantear hipótesis:**
#    - H₀: Las variables son independientes
#    - H₁: Las variables están asociadas
#
# 2. **Calcular frecuencias esperadas:**
#    - E_ij = (Total_fila_i × Total_columna_j) / Total_general
#
# 3. **Calcular estadístico χ²**
#
# 4. **Comparar con valor crítico o p-valor**
#
# 5. **Tomar decisión estadística**
#
# ### 3.3 Supuestos del Chi-cuadrado
#
# - **Observaciones independientes**
# - **Frecuencias esperadas ≥ 5** en al menos 80% de las celdas
# - **Ninguna frecuencia esperada < 1**
#
# ### 3.4 Limitaciones del Chi-cuadrado
#
# - Es sensible al tamaño de la muestra
# - No indica la fuerza de la asociación directamente
# - Solo detecta asociación, no la naturaleza de la relación
#
# ---
#
# ## 4. ANÁLISIS MIXTO: CATEGÓRICA vs CUANTITATIVA
#
# ### 4.1 Enfoque de Análisis
#
# Cuando tenemos una variable categórica y otra cuantitativa:
#
# - **Comparar estadísticas descriptivas** por grupos
# - **Visualizar distribuciones** por categorías
# - **Aplicar pruebas de diferencia de medias** (t-test, ANOVA)
#
# ### 4.2 Herramientas Visuales
#
# - **Box plots**: Mostrar distribución por grupos
# - **Violin plots**: Densidad de distribución por grupos
# - **Histogramas múltiples**: Comparar formas de distribución
# - **Strip plots**: Ver puntos individuales
#
# ---
#
# ## 5. INTERPRETACIÓN Y COMUNICACIÓN DE RESULTADOS
#
# ### 5.1 Principios para Comunicar Correlaciones
#
# 1. **Especificar el tipo** de correlación utilizada
# 2. **Indicar la fuerza** y dirección de la relación
# 3. **Mencionar la significancia** estadística
# 4. **Incluir el tamaño** de la muestra
# 5. **Advertir sobre causalidad** cuando sea relevante
#
# ### 5.2 Principios para Comunicar Asociaciones
#
# 1. **Describir las variables** analizadas
# 2. **Presentar la tabla** de contingencia principal
# 3. **Reportar el estadístico** Chi-cuadrado y p-valor
# 4. **Interpretar en contexto** del problema
# 5. **Identificar patrones** específicos de asociación
#
# ### 5.3 Errores Comunes a Evitar
#
# ❌ **Confundir correlación con causalidad**
#
# ❌ **Interpretar p-hacking** (buscar correlaciones hasta encontrarlas)
#
# ❌ **Ignorar variables confusoras**
#
# ❌ **No verificar supuestos** de las pruebas estadísticas
#
# ❌ **Sobregeneralizar** resultados de muestras específicas
#
# ---
#
# ## 6. CASOS DE APLICACIÓN PRÁCTICA
#
# ### 6.1 Marketing y Ventas
# - Relación entre gasto publicitario y ventas
# - Asociación entre canal de marketing y conversión
# - Correlación entre satisfacción del cliente y fidelidad
#
# ### 6.2 Recursos Humanos
# - Relación entre experiencia y salario
# - Asociación entre nivel educativo y puesto
# - Correlación entre capacitación y desempeño
#
# ### 6.3 Salud Pública
# - Correlación entre ejercicio y presión arterial
# - Asociación entre hábitos alimenticios y enfermedades
# - Relación entre edad y factores de riesgo
#
# ### 6.4 Educación
# - Correlación entre horas de estudio y calificaciones
# - Asociación entre método de enseñanza y aprovechamiento
# - Relación entre recursos escolares y rendimiento
#
# ---
#
# ## 📚 Conceptos Clave para Recordar
#
# **🔑 Correlación:**
# - Mide relación lineal entre variables cuantitativas
# - Va de -1 a +1
# - No implica causalidad
#
# **🔑 Tablas de Contingencia:**
# - Analizan relación entre variables categóricas
# - Permiten calcular frecuencias condicionales
# - Base para pruebas de independencia
#
# **🔑 Chi-cuadrado:**
# - Evalúa independencia entre variables categóricas
# - Requiere supuestos sobre frecuencias esperadas
# - Solo detecta asociación, no su naturaleza
#
# **🔑 Visualización:**
# - Scatter plots para correlaciones
# - Heatmaps para tablas de contingencia
# - Box plots para comparaciones por grupos
# - Siempre incluir líneas de tendencia cuando sea apropiado

# %% [markdown]
# # 📊 Práctica
#
# ## IMPORTACIÓN DE LIBRERÍAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, spearmanr, chi2_contingency
from scipy.stats import chi2
import warnings
warnings.filterwarnings('ignore')

# Configuración de visualizaciones
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 11

# %% [markdown]
# ## CREACIÓN DEL DATASET SOCIOECONÓMICO

# %%
# Configurar semilla para reproducibilidad
np.random.seed(42)
n_samples = 500

print("🏗️ Generando dataset socioeconómico...")

# Generar años de educación (distribución normal)
anos_educacion = np.random.normal(13, 3, n_samples)
anos_educacion = np.clip(anos_educacion, 8, 20)  # Entre 8 y 20 años

# Generar ingresos correlacionados con educación
ingresos_base = 25000 + 3500 * anos_educacion + np.random.normal(0, 8000, n_samples)
ingresos_anuales = np.clip(ingresos_base, 20000, 120000)

# Generar edad
edad = np.random.normal(35, 10, n_samples)
edad = np.clip(edad, 22, 65)

# Generar experiencia laboral (basada en edad y educación)
experiencia = edad - anos_educacion - 18 + np.random.normal(0, 2, n_samples)
experiencia = np.clip(experiencia, 0, 40)

# Generar ocupaciones (variable categórica)
ocupaciones = ['Técnico', 'Profesional', 'Gerente', 'Operario', 'Administrativo']
prob_ocupacion = [0.25, 0.30, 0.15, 0.20, 0.10]
ocupacion = np.random.choice(ocupaciones, n_samples, p=prob_ocupacion)

# Crear nivel educativo categórico
def categorizar_educacion(anos):
    if anos < 12:
        return 'Básica'
    elif anos < 16:
        return 'Media/Técnica'
    else:
        return 'Superior'

nivel_educativo = [categorizar_educacion(anos) for anos in anos_educacion]

# Generar género con ligera brecha salarial
genero = np.random.choice(['Masculino', 'Femenino'], n_samples, p=[0.52, 0.48])
ajuste_genero = np.where(genero == 'Femenino', 0.92, 1.0)
ingresos_anuales = ingresos_anuales * ajuste_genero

# Crear DataFrame
df_socioeconomico = pd.DataFrame({
    'edad': edad.round(0).astype(int),
    'anos_educacion': anos_educacion.round(1),
    'experiencia_laboral': experiencia.round(1),
    'ingresos_anuales': ingresos_anuales.round(0).astype(int),
    'ocupacion': ocupacion,
    'nivel_educativo': nivel_educativo,
    'genero': genero
})

print("✅ Dataset creado exitosamente")
print("📊 Información del dataset:")
print("="*50)
print(f"Tamaño: {df_socioeconomico.shape}")
print(f"Variables: {list(df_socioeconomico.columns)}")
print("\n🔍 Primeras 5 observaciones:")
print(df_socioeconomico.head())

print("\n📈 Estadísticas descriptivas:")
print(df_socioeconomico.describe())
# Out:
# 🏗️ Generando dataset socioeconómico...
# ✅ Dataset creado exitosamente
# 📊 Información del dataset:
# ...
# Tamaño: (500, 7)
# Variables: ['edad', 'anos_educacion', 'experiencia_laboral', 'ingresos_anuales', 'ocupacion', 'nivel_educativo', 'genero']
#
# 🔍 Primeras 5 observaciones:
#    edad  anos_educacion  experiencia_laboral  ingresos_anuales    ocupacion  \
# 0    49            14.5                 18.1             83125  Profesional
# 1    44            12.6                 12.6             84324      Técnico
# 2    36            14.9                  1.0             66112  Profesional
# 3    29            17.6                  0.0             90996      Técnico
# 4    42            12.3                 11.3             62836     Operario
#
#   nivel_educativo     genero
# 0   Media/Técnica  Masculino
# 1   Media/Técnica  Masculino
# 2   Media/Técnica  Masculino
# 3        Superior  Masculino
# 4   Media/Técnica  Masculino
#
# 📈 Estadísticas descriptivas:
# ...

# %%
df_socioeconomico.head()
# Out:
#    edad  anos_educacion  experiencia_laboral  ingresos_anuales    ocupacion  \
# 0    49            14.5                 18.1             83125  Profesional
# 1    44            12.6                 12.6             84324      Técnico
# 2    36            14.9                  1.0             66112  Profesional
# 3    29            17.6                  0.0             90996      Técnico
# 4    42            12.3                 11.3             62836     Operario
#
#   nivel_educativo     genero
# 0   Media/Técnica  Masculino
# 1   Media/Técnica  Masculino
# 2   Media/Técnica  Masculino
# 3        Superior  Masculino
# 4   Media/Técnica  Masculino

# %% [markdown]
# ## 1. ANÁLISIS DE CORRELACIÓN - VARIABLES CUANTITATIVAS

# %%
print("\n" + "="*70)
print("📊 1. ANÁLISIS DE CORRELACIÓN")
print("="*70)

# Seleccionar variables numéricas
variables_numericas = ['edad', 'anos_educacion', 'experiencia_laboral', 'ingresos_anuales']
df_numerico = df_socioeconomico[variables_numericas]

# Calcular matriz de correlación de Pearson
matriz_correlacion = df_numerico.corr()

print("📊 MATRIZ DE CORRELACIÓN (Pearson):")
print(matriz_correlacion.round(3))

# Visualizar matriz de correlación
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# Heatmap básico
sns.heatmap(matriz_correlacion, 
            annot=True, 
            cmap='RdBu_r', 
            center=0,
            square=True,
            fmt='.3f',
            ax=ax[0])
ax[0].set_title('Matriz de Correlación - Completa', fontsize=14, fontweight='bold')

# Heatmap triangular
mask = np.triu(np.ones_like(matriz_correlacion, dtype=bool))
sns.heatmap(matriz_correlacion, 
            annot=True, 
            mask=mask,
            cmap='RdBu_r', 
            center=0,
            square=True,
            fmt='.3f',
            ax=ax[1])
ax[1].set_title('Matriz de Correlación - Triangular', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ...
# 📊 1. ANÁLISIS DE CORRELACIÓN
# ...
# 📊 MATRIZ DE CORRELACIÓN (Pearson):
#                       edad  anos_educacion  experiencia_laboral  \
# edad                 1.000          -0.071                0.915
# anos_educacion      -0.071           1.000               -0.274
# experiencia_laboral  0.915          -0.274                1.000
# ingresos_anuales    -0.008           0.749               -0.178
#
#                      ingresos_anuales
# edad                           -0.008
# anos_educacion                  0.749
# experiencia_laboral            -0.178
# ingresos_anuales                1.000

# %% [markdown]
# 1.1 FUNCIÓN PARA ANÁLISIS DETALLADO DE CORRELACIONES

# %%
def analizar_correlacion(df, var1, var2, metodo='pearson'):
    """
    Función para analizar la correlación entre dos variables
    """
    # Calcular correlación según el método
    if metodo == 'pearson':
        coef, p_valor = pearsonr(df[var1], df[var2])
        tipo_correlacion = "Pearson"
    elif metodo == 'spearman':
        coef, p_valor = spearmanr(df[var1], df[var2])
        tipo_correlacion = "Spearman"
    
    # Interpretación de la fuerza
    if abs(coef) > 0.7:
        fuerza = "FUERTE"
    elif abs(coef) > 0.3:
        fuerza = "MODERADA"
    else:
        fuerza = "DÉBIL"
    
    # Interpretación de la dirección
    if coef > 0:
        direccion = "POSITIVA"
        explicacion = f"A mayor {var1}, mayor {var2}"
    else:
        direccion = "NEGATIVA"
        explicacion = f"A mayor {var1}, menor {var2}"
    
    # Significancia estadística
    significativa = "SÍ" if p_valor < 0.05 else "NO"
    
    print(f"\n🔍 ANÁLISIS: {var1.upper()} vs {var2.upper()}")
    print("="*60)
    print(f"Método: {tipo_correlacion}")
    print(f"Coeficiente: {coef:.4f}")
    print(f"P-valor: {p_valor:.4f}")
    print(f"Fuerza: {fuerza}")
    print(f"Dirección: {direccion}")
    print(f"Significativa (α=0.05): {significativa}")
    print(f"Interpretación: {explicacion}")
    
    return coef, p_valor

# Analizar correlaciones específicas más interesantes
correlaciones_interes = [
    ('anos_educacion', 'ingresos_anuales'),
    ('experiencia_laboral', 'ingresos_anuales'), 
    ('edad', 'experiencia_laboral'),
    ('edad', 'ingresos_anuales')
]

for var1, var2 in correlaciones_interes:
    coef_pearson, _ = analizar_correlacion(df_socioeconomico, var1, var2, 'pearson')
    coef_spearman, _ = analizar_correlacion(df_socioeconomico, var1, var2, 'spearman')
    print(f"Diferencia Pearson-Spearman: {abs(coef_pearson - coef_spearman):.4f}")
    print("-"*60)
# Out:
# 🔍 ANÁLISIS: ANOS_EDUCACION vs INGRESOS_ANUALES
# ...
# Método: Pearson
# Coeficiente: 0.7492
# P-valor: 0.0000
# Fuerza: FUERTE
# Dirección: POSITIVA
# Significativa (α=0.05): SÍ
# Interpretación: A mayor anos_educacion, mayor ingresos_anuales
#
# 🔍 ANÁLISIS: ANOS_EDUCACION vs INGRESOS_ANUALES
# ...
# Método: Spearman
# Coeficiente: 0.7367
# P-valor: 0.0000
# Fuerza: FUERTE
# Dirección: POSITIVA
# Significativa (α=0.05): SÍ
# Interpretación: A mayor anos_educacion, mayor ingresos_anuales
# Diferencia Pearson-Spearman: 0.0125
# ------------------------------------------------------------
#
# 🔍 ANÁLISIS: EXPERIENCIA_LABORAL vs INGRESOS_ANUALES
# ...
# Método: Pearson
# Coeficiente: -0.1778
# P-valor: 0.0001
# Fuerza: DÉBIL
# Dirección: NEGATIVA
# Significativa (α=0.05): SÍ
# Interpretación: A mayor experiencia_laboral, menor ingresos_anuales
#
# 🔍 ANÁLISIS: EXPERIENCIA_LABORAL vs INGRESOS_ANUALES
# ...
# Método: Spearman
# Coeficiente: -0.1842
# P-valor: 0.0000
# Fuerza: DÉBIL
# Dirección: NEGATIVA
# ...

# %% [markdown]
# 1.2 VISUALIZACIÓN DE RELACIONES BIVARIADAS

# %%
print("\n📊 Creando visualizaciones de correlaciones...")

fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.ravel()

relaciones = [
    ('anos_educacion', 'ingresos_anuales', 'Años de Educación', 'Ingresos Anuales ($)'),
    ('experiencia_laboral', 'ingresos_anuales', 'Experiencia Laboral (años)', 'Ingresos Anuales ($)'),
    ('edad', 'experiencia_laboral', 'Edad', 'Experiencia Laboral (años)'),
    ('edad', 'ingresos_anuales', 'Edad', 'Ingresos Anuales ($)')
]

for i, (var_x, var_y, label_x, label_y) in enumerate(relaciones):
    # Scatter plot con línea de tendencia
    sns.scatterplot(data=df_socioeconomico, x=var_x, y=var_y, ax=axes[i], alpha=0.6)
    sns.regplot(data=df_socioeconomico, x=var_x, y=var_y, ax=axes[i], 
                scatter=False, color='red', line_kws={'linewidth': 2})
    
    # Calcular y mostrar correlación
    corr, p_val = pearsonr(df_socioeconomico[var_x], df_socioeconomico[var_y])
    
    axes[i].set_xlabel(label_x, fontweight='bold')
    axes[i].set_ylabel(label_y, fontweight='bold')
    axes[i].set_title(f'{label_x} vs {label_y}\nr = {corr:.3f}, p = {p_val:.4f}', 
                      fontweight='bold')
    axes[i].grid(True, alpha=0.3)

plt.suptitle('📊 Análisis de Correlaciones Bivariadas', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# 📊 Creando visualizaciones de correlaciones...

# %% [markdown]
# ## 2. ANÁLISIS DE TABLAS DE CONTINGENCIA

# %%
print("\n" + "="*70)
print("📊 2. ANÁLISIS DE TABLAS DE CONTINGENCIA")
print("="*70)

def crear_tabla_contingencia(df, var1, var2, mostrar_porcentajes=True):
    """
    Función completa para crear y analizar tablas de contingencia
    """
    print(f"\n📊 TABLA DE CONTINGENCIA: {var1.upper()} vs {var2.upper()}")
    print("="*70)
    
    # Tabla de frecuencias absolutas
    tabla_abs = pd.crosstab(df[var1], df[var2], margins=True)
    print("🔢 FRECUENCIAS ABSOLUTAS:")
    print(tabla_abs)
    
    if mostrar_porcentajes:
        print("\n📈 PORCENTAJES POR FILA:")
        tabla_fila = pd.crosstab(df[var1], df[var2], normalize='index') * 100
        print(tabla_fila.round(2))
        
        print("\n📉 PORCENTAJES POR COLUMNA:")
        tabla_col = pd.crosstab(df[var1], df[var2], normalize='columns') * 100
        print(tabla_col.round(2))
        
        print("\n🎯 PORCENTAJES DEL TOTAL:")
        tabla_total = pd.crosstab(df[var1], df[var2], normalize='all') * 100
        print(tabla_total.round(2))
    
    return tabla_abs

# Analizar relación entre Nivel Educativo y Ocupación
tabla1 = crear_tabla_contingencia(df_socioeconomico, 'nivel_educativo', 'ocupacion')
# Out:
# ...
# 📊 2. ANÁLISIS DE TABLAS DE CONTINGENCIA
# ...
#
# 📊 TABLA DE CONTINGENCIA: NIVEL_EDUCATIVO vs OCUPACION
# ...
# 🔢 FRECUENCIAS ABSOLUTAS:
# ocupacion        Administrativo  Gerente  Operario  Profesional  Técnico  All
# nivel_educativo
# Básica                       24       21        33           61       43  182
# Media/Técnica                22       30        54           79       62  247
# Superior                      7        9        19           20       16   71
# All                          53       60       106          160      121  500
#
# 📈 PORCENTAJES POR FILA:
# ocupacion        Administrativo  Gerente  Operario  Profesional  Técnico
# nivel_educativo
# Básica                    13.19    11.54     18.13        33.52    23.63
# Media/Técnica              8.91    12.15     21.86        31.98    25.10
# Superior                   9.86    12.68     26.76        28.17    22.54
#
# 📉 PORCENTAJES POR COLUMNA:
# ocupacion        Administrativo  Gerente  Operario  Profesional  Técnico
# ...

# %% [markdown]
# 2.1 PRUEBA DE CHI-CUADRADO

# %%
def test_chi_cuadrado(df, var1, var2, alpha=0.05):
    """
    Realizar prueba de chi-cuadrado para independencia
    """
    print(f"\n🧪 PRUEBA DE CHI-CUADRADO: {var1.upper()} vs {var2.upper()}")
    print("="*70)
    
    # Crear tabla de contingencia (sin totales marginales)
    tabla_obs = pd.crosstab(df[var1], df[var2])
    
    # Realizar prueba de chi-cuadrado
    chi2_stat, p_valor, grados_libertad, tabla_esperada = chi2_contingency(tabla_obs)
    
    # Valor crítico
    valor_critico = chi2.ppf(1 - alpha, grados_libertad)
    
    # Resultados
    print(f"Estadístico Chi-cuadrado: {chi2_stat:.4f}")
    print(f"P-valor: {p_valor:.4f}")
    print(f"Grados de libertad: {grados_libertad}")
    print(f"Valor crítico (α={alpha}): {valor_critico:.4f}")
    
    # Interpretación
    if p_valor < alpha:
        decision = "RECHAZAR H₀"
        conclusion = "Las variables SÍ están asociadas (dependientes)"
    else:
        decision = "NO RECHAZAR H₀"
        conclusion = "Las variables NO están asociadas (independientes)"
    
    print(f"\n📋 DECISIÓN: {decision}")
    print(f"🎯 CONCLUSIÓN: {conclusion}")
    
    # Mostrar tabla de frecuencias esperadas
    print(f"\n📊 FRECUENCIAS ESPERADAS:")
    tabla_esperada_df = pd.DataFrame(tabla_esperada, 
                                    index=tabla_obs.index, 
                                    columns=tabla_obs.columns)
    print(tabla_esperada_df.round(2))
    
    # Calcular residuos estandarizados
    residuos = (tabla_obs - tabla_esperada) / np.sqrt(tabla_esperada)
    print(f"\n📐 RESIDUOS ESTANDARIZADOS:")
    print(residuos.round(2))
    
    return chi2_stat, p_valor, tabla_obs, tabla_esperada

# Probar independencia entre variables categóricas
chi2_stat, p_val, tabla_obs, tabla_esp = test_chi_cuadrado(df_socioeconomico, 'nivel_educativo', 'ocupacion')

# Analizar relación entre Género y Ocupación
print("\n" + "="*80)
tabla2 = crear_tabla_contingencia(df_socioeconomico, 'genero', 'ocupacion')
chi2_stat2, p_val2, tabla_obs2, tabla_esp2 = test_chi_cuadrado(df_socioeconomico, 'genero', 'ocupacion')
# Out:
# 🧪 PRUEBA DE CHI-CUADRADO: NIVEL_EDUCATIVO vs OCUPACION
# ...
# Estadístico Chi-cuadrado: 4.4576
# P-valor: 0.8137
# Grados de libertad: 8
# Valor crítico (α=0.05): 15.5073
#
# 📋 DECISIÓN: NO RECHAZAR H₀
# 🎯 CONCLUSIÓN: Las variables NO están asociadas (independientes)
#
# 📊 FRECUENCIAS ESPERADAS:
# ocupacion        Administrativo  Gerente  Operario  Profesional  Técnico
# nivel_educativo
# Básica                    19.29    21.84     38.58        58.24    44.04
# Media/Técnica             26.18    29.64     52.36        79.04    59.77
# Superior                   7.53     8.52     15.05        22.72    17.18
#
# 📐 RESIDUOS ESTANDARIZADOS:
# ocupacion        Administrativo  Gerente  Operario  Profesional  Técnico
# nivel_educativo
# Básica                     1.07    -0.18     -0.90         0.36    -0.16
# Media/Técnica             -0.82     0.07      0.23        -0.00     0.29
# Superior                  -0.19     0.16      1.02        -0.57    -0.29
#
# ...
#
# ...

# %% [markdown]
# 2.2 VISUALIZACIÓN DE TABLAS DE CONTINGENCIA

# %%
print("\n📊 Creando visualizaciones de tablas de contingencia...")

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Heatmap de frecuencias absolutas - Nivel Educativo vs Ocupación
tabla_nivel_ocup = pd.crosstab(df_socioeconomico['nivel_educativo'], df_socioeconomico['ocupacion'])
sns.heatmap(tabla_nivel_ocup, annot=True, fmt='d', cmap='Blues', ax=axes[0,0])
axes[0,0].set_title('Frecuencias Absolutas:\nNivel Educativo vs Ocupación', fontweight='bold')
axes[0,0].set_ylabel('Nivel Educativo', fontweight='bold')
axes[0,0].set_xlabel('Ocupación', fontweight='bold')

# 2. Heatmap de porcentajes por fila
tabla_pct_fila = pd.crosstab(df_socioeconomico['nivel_educativo'], df_socioeconomico['ocupacion'], normalize='index') * 100
sns.heatmap(tabla_pct_fila, annot=True, fmt='.1f', cmap='Greens', ax=axes[0,1])
axes[0,1].set_title('Porcentajes por Fila:\nNivel Educativo vs Ocupación', fontweight='bold')
axes[0,1].set_ylabel('Nivel Educativo', fontweight='bold')
axes[0,1].set_xlabel('Ocupación', fontweight='bold')

# 3. Gráfico de barras agrupadas - Género vs Ocupación
tabla_genero_ocup = pd.crosstab(df_socioeconomico['genero'], df_socioeconomico['ocupacion'])
tabla_genero_ocup.plot(kind='bar', ax=axes[1,0], rot=0)
axes[1,0].set_title('Distribución por Género y Ocupación', fontweight='bold')
axes[1,0].set_ylabel('Frecuencia', fontweight='bold')
axes[1,0].set_xlabel('Género', fontweight='bold')
axes[1,0].legend(title='Ocupación', bbox_to_anchor=(1.05, 1), loc='upper left')

# 4. Gráfico de barras apiladas normalizadas
tabla_pct_genero = pd.crosstab(df_socioeconomico['genero'], df_socioeconomico['ocupacion'], normalize='index') * 100
tabla_pct_genero.plot(kind='bar', stacked=True, ax=axes[1,1], rot=0)
axes[1,1].set_title('Distribución Porcentual por Género', fontweight='bold')
axes[1,1].set_ylabel('Porcentaje (%)', fontweight='bold')
axes[1,1].set_xlabel('Género', fontweight='bold')
axes[1,1].legend(title='Ocupación', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# 📊 Creando visualizaciones de tablas de contingencia...

# %% [markdown]
# ## 3. ANÁLISIS MIXTO: CATEGÓRICA vs CUANTITATIVA

# %%
print("\n" + "="*70)
print("📊 3. ANÁLISIS MIXTO: CATEGÓRICA vs CUANTITATIVA")
print("="*70)

def analizar_categorica_vs_numerica(df, var_cat, var_num):
    """
    Analizar relación entre variable categórica y numérica
    """
    print(f"\n📊 ANÁLISIS: {var_cat.upper()} vs {var_num.upper()}")
    print("="*60)
    
    # Estadísticas descriptivas por grupo
    stats_por_grupo = df.groupby(var_cat)[var_num].agg([
        'count', 'mean', 'median', 'std', 'min', 'max'
    ]).round(2)
    
    print("📈 ESTADÍSTICAS POR GRUPO:")
    print(stats_por_grupo)
    
    # Calcular diferencias entre grupos
    medias = df.groupby(var_cat)[var_num].mean()
    print(f"\n📊 MEDIAS POR GRUPO:")
    for grupo, media in medias.items():
        print(f"  {grupo}: ${media:,.0f}")
    
    # Diferencia máxima entre grupos
    diff_max = medias.max() - medias.min()
    print(f"\n💰 DIFERENCIA MÁXIMA: ${diff_max:,.0f}")
    
    return stats_por_grupo

# Analizar ingresos por género
stats_genero = analizar_categorica_vs_numerica(df_socioeconomico, 'genero', 'ingresos_anuales')

# Analizar ingresos por ocupación
stats_ocupacion = analizar_categorica_vs_numerica(df_socioeconomico, 'ocupacion', 'ingresos_anuales')

# Analizar ingresos por nivel educativo
stats_educacion = analizar_categorica_vs_numerica(df_socioeconomico, 'nivel_educativo', 'ingresos_anuales')
# Out:
# ...
# 📊 3. ANÁLISIS MIXTO: CATEGÓRICA vs CUANTITATIVA
# ...
#
# 📊 ANÁLISIS: GENERO vs INGRESOS_ANUALES
# ...
# 📈 ESTADÍSTICAS POR GRUPO:
#            count      mean   median       std    min     max
# genero
# Femenino     245  65950.89  65850.0  11063.85  36173   93145
# Masculino    255  70161.28  69706.0  12175.98  35202  108572
#
# 📊 MEDIAS POR GRUPO:
#   Femenino: $65,951
#   Masculino: $70,161
#
# 💰 DIFERENCIA MÁXIMA: $4,210
#
# 📊 ANÁLISIS: OCUPACION vs INGRESOS_ANUALES
# ...
# 📈 ESTADÍSTICAS POR GRUPO:
#                 count      mean   median       std    min     max
# ocupacion
# Administrativo     53  66402.53  65854.0  11994.85  35937   93145
# Gerente            60  66884.82  67456.5  12299.86  35202   92263
# Operario          106  70695.60  70981.0  11436.78  45729  108572
# Profesional       160  67040.01  65798.0  10993.18  40095  102448
# Técnico           121  68566.40  68637.0  12656.13  37424  105172
#
# 📊 MEDIAS POR GRUPO:
#   Administrativo: $66,403
#   Gerente: $66,885
# ...

# %% [markdown]
# 3.1 VISUALIZACIONES COMPARATIVAS

# %%
print("\n📊 Creando visualizaciones comparativas...")

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Box plot - Ingresos por Género
sns.boxplot(data=df_socioeconomico, x='genero', y='ingresos_anuales', ax=axes[0,0])
axes[0,0].set_title('Distribución de Ingresos por Género', fontweight='bold')
axes[0,0].set_ylabel('Ingresos Anuales ($)', fontweight='bold')
axes[0,0].set_xlabel('Género', fontweight='bold')

# Añadir medias como puntos rojos
medias_genero = df_socioeconomico.groupby('genero')['ingresos_anuales'].mean()
for i, (genero, media) in enumerate(medias_genero.items()):
    axes[0,0].plot(i, media, 'ro', markersize=8, label='Media' if i == 0 else '')
axes[0,0].legend()

# 2. Box plot - Ingresos por Ocupación
sns.boxplot(data=df_socioeconomico, x='ocupacion', y='ingresos_anuales', ax=axes[0,1])
axes[0,1].set_title('Distribución de Ingresos por Ocupación', fontweight='bold')
axes[0,1].set_ylabel('Ingresos Anuales ($)', fontweight='bold')
axes[0,1].set_xlabel('Ocupación', fontweight='bold')
axes[0,1].tick_params(axis='x', rotation=45)

# 3. Violin plot - Ingresos por Nivel Educativo
sns.violinplot(data=df_socioeconomico, x='nivel_educativo', y='ingresos_anuales', ax=axes[1,0])
axes[1,0].set_title('Distribución de Ingresos por Nivel Educativo', fontweight='bold')
axes[1,0].set_ylabel('Ingresos Anuales ($)', fontweight='bold')
axes[1,0].set_xlabel('Nivel Educativo', fontweight='bold')

# 4. Strip plot con box plot superpuesto
sns.stripplot(data=df_socioeconomico, x='genero', y='ingresos_anuales', 
              size=3, alpha=0.5, ax=axes[1,1])
sns.boxplot(data=df_socioeconomico, x='genero', y='ingresos_anuales', 
            ax=axes[1,1], width=0.3, boxprops={'alpha': 0.7})
axes[1,1].set_title('Ingresos por Género\n(Puntos individuales + Box plot)', fontweight='bold')
axes[1,1].set_ylabel('Ingresos Anuales ($)', fontweight='bold')
axes[1,1].set_xlabel('Género', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 📊 Creando visualizaciones comparativas...

# %% [markdown]
# ## 4. ANÁLISIS AVANZADO: CORRELACIÓN POR GRUPOS

# %%
print("\n" + "="*70)
print("📊 4. ANÁLISIS AVANZADO: CORRELACIÓN POR GRUPOS")
print("="*70)

def correlacion_por_grupos(df, var1, var2, grupo):
    """
    Calcular correlación entre dos variables para cada grupo
    """
    print(f"\n🔍 CORRELACIÓN {var1.upper()} vs {var2.upper()} POR {grupo.upper()}:")
    print("="*60)
    
    correlaciones = {}
    for categoria in df[grupo].unique():
        df_subset = df[df[grupo] == categoria]
        corr, p_val = pearsonr(df_subset[var1], df_subset[var2])
        correlaciones[categoria] = {'correlacion': corr, 'p_valor': p_val}
        
        significativa = "SÍ" if p_val < 0.05 else "NO"
        print(f"{categoria}: r = {corr:.4f}, p = {p_val:.4f}, Significativa: {significativa}")
    
    return correlaciones

# Analizar correlación educación-ingresos por género
corr_edu_ing_genero = correlacion_por_grupos(df_socioeconomico, 
                                            'anos_educacion', 
                                            'ingresos_anuales', 
                                            'genero')

# Visualizar correlaciones por grupos
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Scatter plot por género
for i, genero in enumerate(['Masculino', 'Femenino']):
    df_genero = df_socioeconomico[df_socioeconomico['genero'] == genero]
    
    sns.scatterplot(data=df_genero, x='anos_educacion', y='ingresos_anuales', 
                   ax=axes[i], alpha=0.6)
    sns.regplot(data=df_genero, x='anos_educacion', y='ingresos_anuales', 
               ax=axes[i], scatter=False, color='red')
    
    corr = corr_edu_ing_genero[genero]['correlacion']
    p_val = corr_edu_ing_genero[genero]['p_valor']
    
    axes[i].set_title(f'Educación vs Ingresos - {genero}\nr = {corr:.3f}, p = {p_val:.4f}', 
                      fontweight='bold')
    axes[i].set_xlabel('Años de Educación', fontweight='bold')
    axes[i].set_ylabel('Ingresos Anuales ($)', fontweight='bold')
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ...
# 📊 4. ANÁLISIS AVANZADO: CORRELACIÓN POR GRUPOS
# ...
#
# 🔍 CORRELACIÓN ANOS_EDUCACION vs INGRESOS_ANUALES POR GENERO:
# ...
# Masculino: r = 0.7526, p = 0.0000, Significativa: SÍ
# Femenino: r = 0.7792, p = 0.0000, Significativa: SÍ

# %% [markdown]
# ## 📚 MATERIAL ADICIONAL
#
# ---
#
# ### 🌐 **ENLACES RECOMENDADOS**
#
# #### **📖 Documentación Oficial**
#
# - **SciPy Stats - Funciones Estadísticas**: https://docs.scipy.org/doc/scipy/reference/stats.html
# - **Seaborn - Visualizaciones Estadísticas**: https://seaborn.pydata.org/tutorial/regression.html
# - **Matplotlib - Scatter Plots**: https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html
#
# ---
#
# ### 🛠️ **HERRAMIENTAS Y SOFTWARE**
#
# #### **💻 Entornos de Desarrollo**
# - **Jupyter Lab**: https://jupyterlab.readthedocs.io/en/stable/
# - **Google Colab**: https://colab.research.google.com/
# - **VSCode con extensiones Python**: https://code.visualstudio.com/docs/python/python-tutorial
# - **PyCharm Community**: https://www.jetbrains.com/pycharm/
#
# #### **📊 Librerías Especializadas**
# - **Pingouin - Estadísticas en Python**: https://pingouin-stats.org/
# - **Statsmodels - Modelos Estadísticos**: https://www.statsmodels.org/stable/index.html
# - **Plotly - Visualizaciones Interactivas**: https://plotly.com/python/
#
# ---
#
# ### 📊 **DATASETS PARA PRÁCTICA**
#
# #### **🗂️ Repositorios de Datos**
# 1. **UCI Machine Learning Repository**: https://archive.ics.uci.edu/ml/index.php
# 2. **Kaggle Datasets**: https://www.kaggle.com/datasets
# 3. **Google Dataset Search**: https://datasetsearch.research.google.com/
# 4. **Data.gov**: https://www.data.gov/
# 5. **Our World in Data**: https://ourworldindata.org/
#
# #### **📈 Datasets Específicos para Análisis Bivariado**
# - **Boston Housing**: https://www.kaggle.com/c/boston-housing
# - **Titanic Dataset**: https://www.kaggle.com/c/titanic
# - **California Housing**: https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset
# - **Wine Quality**: https://archive.ics.uci.edu/ml/datasets/wine+quality
# - **Student Performance**: https://archive.ics.uci.edu/ml/datasets/student+performance
#
# ---
