# %% [markdown]
# # 📊 SESIÓN 1: Fundamentos y Configuración del Entorno
# ## *Introducción a la Estadística Descriptiva*
#
# ---
#
# ## 🎯 **Objetivos de Aprendizaje**
#
# Al finalizar esta sesión, serás capaz de:
# - ✅ Comprender qué es la estadística descriptiva y su importancia
# - ✅ Diferenciar entre estadística descriptiva e inferencial
# - ✅ Identificar y clasificar diferentes tipos de variables
# - ✅ Configurar tu entorno de trabajo en Python
# - ✅ Realizar las primeras exploraciones de datos
#
# ---
#
# ## 📖 **PARTE 1: ¿Qué es la Estadística Descriptiva?**
#
# ### **Definición**
#
# > **La estadística descriptiva** es la rama de la estadística que se encarga de **recopilar, organizar, resumir y presentar datos** de manera que podamos entender las características principales de un conjunto de información.
#
# ### **🔍 Diferencias Clave**
#
# | Estadística Descriptiva | Estadística Inferencial |
# |------------------------|------------------------|
# | **Describe** los datos que tenemos | **Infiere** conclusiones sobre poblaciones |
# | **Resume** la información disponible | **Predice** y generaliza |
# | **No hace predicciones** | **Hace estimaciones y prueba hipótesis** |
# | Ejemplo: "El 60% de nuestros clientes son mujeres" | Ejemplo: "Con 95% de confianza, entre 55% y 65% de todos los clientes son mujeres" |
#
# ### **🌍 Aplicaciones en la Vida Real**
#
# #### **1. Negocios y Marketing**
# - Análisis de ventas mensuales
# - Perfil demográfico de clientes
# - Rendimiento de campañas publicitarias
#
# #### **2. Salud Pública**
# - Estadísticas de enfermedades por región
# - Efectividad de tratamientos médicos
# - Análisis de factores de riesgo
#
# #### **3. Educación**
# - Rendimiento académico por grado
# - Tasas de deserción escolar
# - Evaluación de métodos de enseñanza
#
# #### **4. Deportes**
# - Estadísticas de jugadores
# - Análisis de rendimiento de equipos
# - Comparación de temporadas
#
# #### **5. Gobierno y Política**
# - Censos poblacionales
# - Índices económicos
# - Análisis de resultados electorales
#
# ### **💡 ¿Por qué es Importante?**
#
# 1. **Toma de Decisiones Informadas**: Los datos nos ayudan a decidir basándonos en hechos, no en intuiciones
# 2. **Comunicación Efectiva**: Los números bien presentados comunican mejor que miles de palabras
# 3. **Detección de Patrones**: Permite identificar tendencias y anomalías
# 4. **Base para Análisis Avanzados**: Es el fundamento para machine learning e inteligencia artificial
#
# ---
#
# ## 📊 **PARTE 2: Tipos de Variables**
#
# ### **🔢 Clasificación Principal**
#
# ```
# VARIABLES
# ├── CUALITATIVAS (Categóricas)
# │   ├── Nominales
# │   └── Ordinales
# └── CUANTITATIVAS (Numéricas)
#     ├── Discretas
#     └── Continuas
# ```
#
# ### **Variables Cualitativas (Categóricas)**
#
# #### **Variables Nominales**
# - **Definición**: Categorías sin orden natural
# - **Características**: Solo se pueden contar, no tienen jerarquía
# - **Ejemplos**:
#   - Género: Masculino, Femenino, Otro
#   - Color de ojos: Azul, Verde, Café, Negro
#   - Estado civil: Soltero, Casado, Divorciado, Viudo
#   - Marca de automóvil: Toyota, Ford, BMW, etc.
#
# #### **Variables Ordinales**
# - **Definición**: Categorías con orden natural o jerarquía
# - **Características**: Se pueden ordenar de menor a mayor (o viceversa)
# - **Ejemplos**:
#   - Nivel educativo: Primaria < Secundaria < Universidad < Posgrado
#   - Satisfacción: Muy Insatisfecho < Insatisfecho < Neutral < Satisfecho < Muy Satisfecho
#   - Tamaño: Pequeño < Mediano < Grande
#   - Calificaciones: A > B > C > D > F
#
# ### **Variables Cuantitativas (Numéricas)**
#
# #### **Variables Discretas**
# - **Definición**: Solo pueden tomar valores enteros específicos
# - **Características**: Se pueden contar, hay "saltos" entre valores
# - **Ejemplos**:
#   - Número de hijos: 0, 1, 2, 3, 4...
#   - Cantidad de productos vendidos: 10, 25, 100...
#   - Número de empleados: 5, 50, 500...
#   - Calificación en examen: 0-100 (enteros)
#
# #### **Variables Continuas**
# - **Definición**: Pueden tomar cualquier valor dentro de un rango
# - **Características**: Se pueden medir, no hay "saltos"
# - **Ejemplos**:
#   - Altura: 1.75m, 1.758m, 1.7581m...
#   - Peso: 65.3kg, 65.35kg, 65.351kg...
#   - Temperatura: 23.4°C, 23.45°C...
#   - Tiempo: 5.25 segundos, 5.251 segundos...
#
# ### **📏 Escalas de Medición**
#
# #### **Escala Nominal**
# - Solo categorías diferentes
# - Operaciones: Contar frecuencias
# - Ejemplo: Colores, marcas
#
# #### **Escala Ordinal**
# - Categorías ordenadas
# - Operaciones: Contar, ordenar
# - Ejemplo: Ranking, calificaciones con letras
#
# #### **Escala de Intervalo**
# - Números con intervalos iguales, pero sin cero absoluto
# - Operaciones: Sumar, restar, promedios
# - Ejemplo: Temperatura en Celsius (0°C no significa "ausencia de temperatura")
#
# #### **Escala de Razón**
# - Números con intervalos iguales y cero absoluto
# - Operaciones: Todas las operaciones matemáticas
# - Ejemplo: Altura, peso, ingresos (0 significa "ausencia total")
#
# ### **🎯 Ejercicio de Identificación**
#
# **Clasifica las siguientes variables:**
#
# 1. **Número de ventanas en una casa** → _________
# 2. **Región geográfica (Norte, Sur, Este, Oeste)** → _________
# 3. **Salario anual en pesos** → _________
# 4. **Nivel de dolor (Bajo, Medio, Alto)** → _________
# 5. **Tiempo para completar una tarea** → _________
# 6. **Número de identificación del empleado** → _________
#
# <details>
# <summary>💡 Ver respuestas</summary>
#
# 1. **Cuantitativa Discreta** (se cuenta, valores enteros)
# 2. **Cualitativa Nominal** (categorías sin orden)
# 3. **Cuantitativa Continua** (se puede medir con decimales)
# 4. **Cualitativa Ordinal** (categorías con orden natural)
# 5. **Cuantitativa Continua** (se puede medir con precisión)
# 6. **Cualitativa Nominal** (aunque sea número, solo identifica)
# </details>
#
# ---
#
# ## 💻 **PARTE 3: Configuración del Entorno Python**
#
# ### **🐍 ¿Por qué Python para Estadística?**
#
# 1. **Facilidad de Aprendizaje**: Sintaxis simple y legible
# 2. **Librerías Especializadas**: pandas, numpy, matplotlib, seaborn
# 3. **Comunidad Activa**: Mucho soporte y recursos
# 4. **Versatilidad**: Desde análisis básico hasta machine learning
# 5. **Gratuito y Open Source**: Sin costos de licencia
#
# ### **📦 Librerías Principales**
#
# #### **pandas** 🐼
# - **Propósito**: Manipulación y análisis de datos
# - **Funciones clave**: Leer archivos, filtrar, agrupar, calcular estadísticas
# - **Analogía**: Como Excel pero más poderoso
#
# #### **numpy** 🔢
# - **Propósito**: Operaciones matemáticas y numéricas
# - **Funciones clave**: Cálculos estadísticos, operaciones con arrays
# - **Analogía**: La calculadora científica de Python
#
# #### **matplotlib** 📈
# - **Propósito**: Creación de gráficos básicos
# - **Funciones clave**: Líneas, barras, histogramas
# - **Analogía**: El "PowerPoint" para gráficos
#
# #### **seaborn** 🎨
# - **Propósito**: Visualizaciones estadísticas avanzadas y estéticas
# - **Funciones clave**: Gráficos especializados para estadística
# - **Analogía**: El "diseñador gráfico" de matplotlib
#
# ### **🛠️ Instalación**
#
# #### **Opción 1: Anaconda (Recomendada para principiantes)**
# ```bash
# # Descarga Anaconda desde: https://www.anaconda.com/
# # Incluye Python + todas las librerías + Jupyter Notebook
# ```
#
# #### **Opción 2: pip (Para usuarios con Python ya instalado)**
# ```bash
# pip install pandas numpy matplotlib seaborn jupyter
# ```
#
# ### **📓 Jupyter Notebook**
# - **¿Qué es?**: Entorno interactivo para escribir código y ver resultados
# - **Ventajas**:
#   - Combina código, texto y gráficos
#   - Ideal para análisis exploratorio
#   - Fácil de compartir
# - **Cómo abrir**: `jupyter notebook` en la terminal
#
# ---
#
# ## 🎯 **PARTE 4: Primeros Conceptos Estadísticos**
#
# ### **🔍 El Proceso de Análisis Estadístico**
#
# ```
# 1. RECOLECCIÓN → 2. ORGANIZACIÓN → 3. ANÁLISIS → 4. INTERPRETACIÓN → 5. COMUNICACIÓN
# ```
#
# #### **1. Recolección de Datos**
# - Encuestas, experimentos, observaciones
# - Bases de datos existentes
# - Sensores y dispositivos automáticos
#
# #### **2. Organización**
# - Limpieza de datos
# - Estructuración en tablas
# - Clasificación por variables
#
# #### **3. Análisis Descriptivo**
# - Medidas de tendencia central
# - Medidas de dispersión
# - Visualizaciones
#
# #### **4. Interpretación**
# - ¿Qué significan los números?
# - ¿Qué patrones encontramos?
# - ¿Qué preguntas surgen?
#
# #### **5. Comunicación**
# - Reportes claros
# - Visualizaciones efectivas
# - Recomendaciones accionables
#
# ### **📊 Población vs. Muestra**
#
# #### **Población**
# - **Definición**: Conjunto completo de elementos que queremos estudiar
# - **Ejemplos**:
#   - Todos los estudiantes universitarios de Colombia
#   - Todas las empresas tecnológicas del mundo
#   - Todos los clientes de una tienda
#
# #### **Muestra**
# - **Definición**: Subconjunto representativo de la población
# - **¿Por qué usar muestras?**
#   - Costo: Es más económico
#   - Tiempo: Es más rápido
#   - Practicidad: A veces es imposible estudiar toda la población
#
# ### **📈 Parámetros vs. Estadísticos**
#
# | Parámetros | Estadísticos |
# |------------|-------------|
# | **Describen la población** | **Describen la muestra** |
# | Usualmente **desconocidos** | **Calculables** a partir de datos |
# | Se representan con letras **griegas** (μ, σ) | Se representan con letras **latinas** (x̄, s) |
# | Ejemplo: μ = Edad promedio de todos los ciudadanos | Ejemplo: x̄ = Edad promedio en nuestra muestra de 1000 personas |
#
# ---
#
# ## 🚀 **PARTE 5: Preparación para la Práctica**
#
# ### **🎯 Objetivos de la Sesión Práctica**
#
# En la parte práctica aprenderemos a:
# 1. **Configurar** nuestro entorno de trabajo
# 2. **Importar** las librerías necesarias
# 3. **Cargar** nuestros primeros datasets
# 4. **Explorar** los datos básicamente
# 5. **Identificar** tipos de variables en datos reales
#
# ### **📊 Datasets que Utilizaremos**
#
# #### **Dataset 1: Iris** 🌸
# - **Descripción**: Mediciones de flores iris (150 muestras)
# - **Variables**: Longitud y ancho de pétalos y sépalos, especie
# - **Uso**: Perfecto para aprender conceptos básicos
#
# #### **Dataset 2: Estudiantes** 🎓
# - **Descripción**: Información de estudiantes (notas, edad, género)
# - **Variables**: Mix de categóricas y numéricas
# - **Uso**: Ejemplos prácticos y relacionables
#
# ### **💡 Consejos para Principiantes**
#
# 1. **No te preocupes por memorizar sintaxis**: Se aprende con la práctica
# 2. **Experimenta**: Cambia valores y observa qué pasa
# 3. **Lee los errores**: Python te dice exactamente qué está mal
# 4. **Usa la documentación**: Cada función tiene ayuda incorporada
# 5. **Practica regularmente**: 15 minutos diarios es mejor que 3 horas una vez por semana
#
# ---
#
# ## 📝 **RESUMEN DE CONCEPTOS CLAVE**
#
# ### **✅ Puntos Importantes para Recordar**
#
# 1. **Estadística Descriptiva**: Describe y resume datos que ya tenemos
# 2. **Variables Cualitativas**: Categorías (nominal sin orden, ordinal con orden)
# 3. **Variables Cuantitativas**: Números (discreta = enteros, continua = cualquier valor)
# 4. **Escalas de Medición**: Nominal < Ordinal < Intervalo < Razón
# 5. **Python + pandas + numpy + matplotlib + seaborn** = Kit completo para estadística
#
# ### **🎯 Próximo Paso**
# En la práctica aplicaremos estos conceptos con datos reales. ¡Prepárate para escribir tu primer código estadístico!
#
# ---
#
# ## 🤔 **Preguntas de Autoevaluación**
#
# **Antes de continuar con la práctica, reflexiona:**
#
# 1. ¿Puedes explicar la diferencia entre estadística descriptiva e inferencial con tus propias palabras?
# 2. ¿Sabes identificar si una variable es cualitativa o cuantitativa?
# 3. ¿Entiendes por qué usamos muestras en lugar de poblaciones completas?
# 4. ¿Tienes clara la diferencia entre parámetros y estadísticos?
#
# *Si respondiste "sí" a todas, ¡estás listo para la práctica! Si tienes dudas en alguna, revisa esa sección antes de continuar.*

# %% [markdown]
# # 📊 PRÁCTICA
# ## Paso 1: Configuración del Entorno y Primeros Pasos con Datos

# %%
# Librerías fundamentales para estadística descriptiva
import pandas as pd              # Para manipulación de datos
import numpy as np               # Para cálculos matemáticos y estadísticos
import matplotlib.pyplot as plt  # Para gráficos básicos
import seaborn as sns           # Para gráficos estadísticos avanzados

# %% [markdown]
# ## PASO 2: CARGA DE NUESTRO PRIMER DATASET - IRIS

# %%
# Cargamos el famoso dataset Iris
from sklearn.datasets import load_iris
iris_data = load_iris()

# Convertimos a DataFrame de pandas para facilitar el análisis
iris_df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)
iris_df['species'] = iris_data.target
iris_df['species'] = iris_df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

print("✅ Dataset Iris cargado exitosamente")
print(f"📏 Dimensiones: {iris_df.shape[0]} filas × {iris_df.shape[1]} columnas")
# Out:
# ✅ Dataset Iris cargado exitosamente
# 📏 Dimensiones: 150 filas × 5 columnas

# %% [markdown]
# ## PASO 3: EXPLORACIÓN INICIAL DE LOS DATOS

# %%
print("\n" + "="*70)
print("🔍 EXPLORACIÓN INICIAL - CONOCIENDO NUESTROS DATOS")
print("="*70)

print("\n1️⃣ PRIMERAS 5 FILAS (método .head()):")
print(iris_df.head())

print("\n2️⃣ INFORMACIÓN GENERAL DEL DATASET (método .info()):")
iris_df.info()

print("\n3️⃣ ESTADÍSTICAS DESCRIPTIVAS BÁSICAS (método .describe()):")
print(iris_df.describe())

print("\n4️⃣ NOMBRES DE TODAS LAS COLUMNAS:")
print("Columnas:", list(iris_df.columns))

print("\n5️⃣ TIPOS DE DATOS POR COLUMNA:")
print(iris_df.dtypes)
# Out:
# ...
# 🔍 EXPLORACIÓN INICIAL - CONOCIENDO NUESTROS DATOS
# ...
#
# 1️⃣ PRIMERAS 5 FILAS (método .head()):
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# 2️⃣ INFORMACIÓN GENERAL DEL DATASET (método .info()):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
# ...

# %% [markdown]
# ## PASO 4: IDENTIFICACIÓN DE TIPOS DE VARIABLES

# %%
print("\n" + "="*70)
print("🏷️ IDENTIFICACIÓN DE TIPOS DE VARIABLES")
print("="*70)

# Análisis manual de cada variable
variables_info = {
    'sepal length (cm)': {
        'tipo': 'Cuantitativa Continua',
        'razon': 'Se puede medir con decimales, representa longitud',
        'escala': 'Razón (tiene cero absoluto)'
    },
    'sepal width (cm)': {
        'tipo': 'Cuantitativa Continua',
        'razon': 'Se puede medir con decimales, representa ancho',
        'escala': 'Razón (tiene cero absoluto)'
    },
    'petal length (cm)': {
        'tipo': 'Cuantitativa Continua',
        'razon': 'Se puede medir con decimales, representa longitud',
        'escala': 'Razón (tiene cero absoluto)'
    },
    'petal width (cm)': {
        'tipo': 'Cuantitativa Continua',
        'razon': 'Se puede medir con decimales, representa ancho',
        'escala': 'Razón (tiene cero absoluto)'
    },
    'species': {
        'tipo': 'Cualitativa Nominal',
        'razon': 'Categorías de especies sin orden natural',
        'escala': 'Nominal (solo categorías diferentes)'
    }
}

for variable, info in variables_info.items():
    print(f"\n🏷️ {variable}:")
    print(f"   Tipo: {info['tipo']}")
    print(f"   Razón: {info['razon']}")
    print(f"   Escala: {info['escala']}")
# Out:
# ...
# 🏷️ IDENTIFICACIÓN DE TIPOS DE VARIABLES
# ...
#
# 🏷️ sepal length (cm):
#    Tipo: Cuantitativa Continua
#    Razón: Se puede medir con decimales, representa longitud
#    Escala: Razón (tiene cero absoluto)
#
# 🏷️ sepal width (cm):
#    Tipo: Cuantitativa Continua
#    Razón: Se puede medir con decimales, representa ancho
#    Escala: Razón (tiene cero absoluto)
#
# 🏷️ petal length (cm):
#    Tipo: Cuantitativa Continua
#    Razón: Se puede medir con decimales, representa longitud
#    Escala: Razón (tiene cero absoluto)
#
# 🏷️ petal width (cm):
#    Tipo: Cuantitativa Continua
#    Razón: Se puede medir con decimales, representa ancho
#    Escala: Razón (tiene cero absoluto)
#
# 🏷️ species:
#    Tipo: Cualitativa Nominal
#    Razón: Categorías de especies sin orden natural
#    Escala: Nominal (solo categorías diferentes)

# %% [markdown]
# ## PASO 5: ANÁLISIS ESPECÍFICO POR TIPO DE VARIABLE

# %%
print("\n" + "="*70)
print("📈 ANÁLISIS ESPECÍFICO POR TIPO DE VARIABLE")
print("="*70)

# ANÁLISIS DE VARIABLES CUANTITATIVAS
print("\n🔢 VARIABLES CUANTITATIVAS - Medidas básicas:")
numeric_vars = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

for var in numeric_vars:
    print(f"\n📊 {var}:")
    print(f"   Promedio: {iris_df[var].mean():.2f}")
    print(f"   Mediana: {iris_df[var].median():.2f}")
    print(f"   Mínimo: {iris_df[var].min():.2f}")
    print(f"   Máximo: {iris_df[var].max():.2f}")
    print(f"   Desviación estándar: {iris_df[var].std():.2f}")

# ANÁLISIS DE VARIABLES CUALITATIVAS
print("\n🏷️ VARIABLE CUALITATIVA - Frecuencias:")
print("\n📊 Distribución de especies:")
especies_frecuencia = iris_df['species'].value_counts()
print(especies_frecuencia)

print("\n📊 Porcentajes por especie:")
especies_porcentaje = iris_df['species'].value_counts(normalize=True) * 100
for especie, porcentaje in especies_porcentaje.items():
    print(f"   {especie}: {porcentaje:.1f}%")
# Out:
# ...
# 📈 ANÁLISIS ESPECÍFICO POR TIPO DE VARIABLE
# ...
#
# 🔢 VARIABLES CUANTITATIVAS - Medidas básicas:
#
# 📊 sepal length (cm):
#    Promedio: 5.84
#    Mediana: 5.80
#    Mínimo: 4.30
#    Máximo: 7.90
#    Desviación estándar: 0.83
#
# 📊 sepal width (cm):
#    Promedio: 3.06
#    Mediana: 3.00
#    Mínimo: 2.00
#    Máximo: 4.40
#    Desviación estándar: 0.44
#
# 📊 petal length (cm):
#    Promedio: 3.76
#    Mediana: 4.35
#    Mínimo: 1.00
#    Máximo: 6.90
#    Desviación estándar: 1.77
#
# 📊 petal width (cm):
#    Promedio: 1.20
#    Mediana: 1.30
#    Mínimo: 0.10
#    Máximo: 2.50
#    Desviación estándar: 0.76
#
# 🏷️ VARIABLE CUALITATIVA - Frecuencias:
#
# 📊 Distribución de especies:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
# 📊 Porcentajes por especie:
#    setosa: 33.3%
#    versicolor: 33.3%
#    virginica: 33.3%

# %% [markdown]
# ## PASO 6: PRIMERAS VISUALIZACIONES

# %%
print("\n" + "="*70)
print("📊 CREANDO NUESTRAS PRIMERAS VISUALIZACIONES")
print("="*70)

# Configuramos el estilo de los gráficos
plt.style.use('default')
sns.set_palette("husl")

# GRÁFICO 1: Histograma de una variable cuantitativa
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.hist(iris_df['sepal length (cm)'], bins=15, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribución de Longitud del Sépalo')
plt.xlabel('Longitud (cm)')
plt.ylabel('Frecuencia')
plt.grid(True, alpha=0.3)

# GRÁFICO 2: Gráfico de barras para variable categórica
plt.subplot(1, 3, 2)
especies_count = iris_df['species'].value_counts()
plt.bar(especies_count.index, especies_count.values, color=['coral', 'lightgreen', 'gold'])
plt.title('Cantidad por Especie')
plt.xlabel('Especie')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)

# GRÁFICO 3: Gráfico de dispersión (dos variables cuantitativas)
plt.subplot(1, 3, 3)
for especie in iris_df['species'].unique():
    datos_especie = iris_df[iris_df['species'] == especie]
    plt.scatter(datos_especie['sepal length (cm)'], datos_especie['sepal width (cm)'], 
               label=especie, alpha=0.7, s=50)

plt.title('Longitud vs Ancho del Sépalo')
plt.xlabel('Longitud (cm)')
plt.ylabel('Ancho (cm)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("✅ Gráficos creados exitosamente")
# Out:
# ...
# 📊 CREANDO NUESTRAS PRIMERAS VISUALIZACIONES
# ...
# ✅ Gráficos creados exitosamente

# %% [markdown]
# ### **Métodos Esenciales Aprendidos**
# | Método | Propósito | Ejemplo de Uso |
# |--------|-----------|---------------|
# | `.head()` | Primeras filas | `df.head(10)` |
# | `.info()` | Información general | `df.info()` |
# | `.describe()` | Estadísticas básicas | `df.describe()` |
# | `.shape` | Dimensiones | `df.shape` |
# | `.dtypes` | Tipos de datos | `df.dtypes` |
# | `.value_counts()` | Frecuencias | `df['columna'].value_counts()` |
#
# ---
#
# ## 🎯 **Ejercicios de Consolidación**
#
# ### **Para Practicar en Casa**
#
# 1. **🔍 Identificación de Variables**
#    - Clasifica 10 variables de tu área de trabajo/estudio
#    - Justifica cada clasificación
#
# 2. **💻 Práctica con Código**
#    - Crea un dataset con información personal (amigos, familia)
#    - Aplica todos los métodos aprendidos
#
# 3. **📊 Análisis Exploratorio**
#    - Descarga un dataset de Kaggle
#    - Realiza exploración inicial siguiendo nuestros pasos
#
# ### **Preguntas de Autoevaluación**
#
# 1. ¿Puedes explicar por qué la "satisfacción del cliente" es ordinal y no nominal?
# 2. ¿Cuál es la diferencia práctica entre una variable discreta y continua?
# 3. ¿Por qué usamos muestras en lugar de poblaciones completas?
# 4. ¿Qué información nos da el método `.describe()` y cuándo es útil?
#
# ---
#
# ## 📚 **Recursos Adicionales**
#
# ### **🔗 Enlaces Útiles**
# - [Pandas Documentation](https://pandas.pydata.org/docs/)
# - [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html)
# - [Kaggle Learn - Python](https://www.kaggle.com/learn/python)
#
# ---
#
# ## 🚀 **Preparación para Sesión 2**
#
# ### **📋 Checklist de Preparación**
# - [ ] Entorno Python funcionando correctamente
# - [ ] Datasets guardados (`iris_dataset.csv`, `estudiantes_dataset.csv`)
# - [ ] Conceptos de tipos de variables claros
# - [ ] Métodos básicos de pandas practicados
#
# ### **🎯 Qué Viene en la Sesión 2**
# - **📊 Medidas de Tendencia Central**: Media, mediana, moda
# - **⚖️ Cuándo usar cada medida**: Criterios de selección
# - **🎯 Efecto de outliers**: Impacto en las medidas
# - **💻 Implementación práctica**: Cálculos manuales vs automáticos
# - **📈 Visualización**: Representación gráfica de tendencias centrales
#
# ### **💡 Consejo para el Éxito**
# *"La estadística no es solo números, es una forma de pensar sobre los datos y encontrar historias que nos ayuden a tomar mejores decisiones."*
#
# ---
